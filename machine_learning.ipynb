# %%
import pandas as pd
import seaborn as sns

from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error,mean_absolute_error, r2_score,root_mean_squared_error

from xgboost import XGBRegressor

import pickle

# %%
df = pd.read_csv("preprocessed_demand_data.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Store ID', 'Product ID', 'Category', 'Region',
#        'Inventory Level', 'Units Sold', 'Units Ordered', 'Price', 'Discount',
#        'Weather Condition', 'Promotion', 'Competitor Pricing', 'Seasonality',
#        'Epidemic', 'Demand', 'Year', 'Month', 'Day', 'Weekday',
#        'Discounted Price', 'Sell through Rate'],
#       dtype='str')

# %%
features = ["Price", "Discount", "Inventory Level", "Promotion", "Competitor Pricing", "Category"]

# %%
target = "Demand"

# %%
features
# Out:
# ['Price',
#  'Discount',
#  'Inventory Level',
#  'Promotion',
#  'Competitor Pricing',
#  'Category']

# %%
X = df[features].copy()

# %%
Y= df[target]

# %%
Y
# Out:
# 0        115
# 1        229
# 2        157
# 3         52
# 4         59
#         ...
# 75995     64
# 75996    137
# 75997     68
# 75998     84
# 75999     73
# Name: Demand, Length: 76000, dtype: int64

# %%
X
# Out:
#         Price  Discount  Inventory Level  Promotion  Competitor Pricing  \
# 0       72.72         5              195          0               85.73
# 1       80.16        15              117          1               92.02
# 2       62.94        10              247          1               60.08
# 3       87.63        10              139          0               85.19
# 4       54.41         0              152          0               51.63
# ...       ...       ...              ...        ...                 ...
# 75995   29.80         5              233          0               32.23
# 75996   42.92         5              137          0               40.73
# 75997   17.81        10              197          0               19.41
# 75998  151.72         0              125          0              143.71
# 75999   25.78        10              126          0               29.32
#
#           Category
# 0      Electronics
# 1         Clothing
# 2         Clothing
# 3      Electronics
# ...

# %%
label_encoders={}
categorical_cols = X.select_dtypes(include=['object']).columns
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_10868\2955233859.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_cols = X.select_dtypes(include=['object']).columns

# %%
categorical_cols
# Out:
# Index(['Category'], dtype='str')

# %%
for col in categorical_cols:
    le = LabelEncoder()
    X[col] = le.fit_transform(X[col])
    label_encoders[col] = le

# %%
label_encoders
# Out:
# {'Category': LabelEncoder()}

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
X
# Out:
#         Price  Discount  Inventory Level  Promotion  Competitor Pricing  \
# 0       72.72         5              195          0               85.73
# 1       80.16        15              117          1               92.02
# 2       62.94        10              247          1               60.08
# 3       87.63        10              139          0               85.19
# 4       54.41         0              152          0               51.63
# ...       ...       ...              ...        ...                 ...
# 75995   29.80         5              233          0               32.23
# 75996   42.92         5              137          0               40.73
# 75997   17.81        10              197          0               19.41
# 75998  151.72         0              125          0              143.71
# 75999   25.78        10              126          0               29.32
#
#        Category
# 0             1
# 1             0
# 2             0
# 3             1
# ...

# %%
xgb=XGBRegressor(objective='reg:squarederror', n_jobs=-1)

# %%
param_dict = {'n_estimators': [ 200, 300,500], 'max_depth': [3, 4, 6, 8], 'learning_rate': [0.01, 0.05, 0.1], 'subsample': [0.7, 0.8, 1.0], 'colsample_bytree': [0.7, 0.8, 1.0], 'min_child_weight': [1, 3, 5]}

# %%
random_search = RandomizedSearchCV(estimator=xgb, param_distributions=param_dict, n_iter=25, scoring='neg_mean_squared_error', cv=3, verbose=1, n_jobs=-1)

# %%
random_search.fit(X_train, Y_train)
# Out:
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# RandomizedSearchCV(cv=3,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, device=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, feature_types=None,
#                                           feature_weights=None, gamma=None,
#                                           grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraint...
# ...

# %%
random_search.best_params_
# Out:
# {'subsample': 0.8,
#  'n_estimators': 200,
#  'min_child_weight': 3,
#  'max_depth': 6,
#  'learning_rate': 0.05,
#  'colsample_bytree': 1.0}

# %%
best_model=random_search.best_estimator_

# %%
y_pred=best_model.predict(X_test)

# %%
root_mean_squared_error(Y_test, y_pred)
# Out:
# 35.581298828125

# %%
best_model.feature_importances_
# Out:
# array([0.06979538, 0.01807256, 0.01442959, 0.6849462 , 0.02607421,
#        0.18668205], dtype=float32)

# %%
feature_importances = pd.Series(best_model.feature_importances_, index=X.columns).sort_values(ascending=False)

# %%
feature_importances
# Out:
# Promotion             0.684946
# Category              0.186682
# Price                 0.069795
# Competitor Pricing    0.026074
# Discount              0.018073
# Inventory Level       0.014430
# dtype: float32

# %%
feature_importances.plot(kind="bar", title="Feature Importances")
# Out:
# <Axes: title={'center': 'Feature Importances'}>

# %%
with open("label_encoders.pkl", "wb") as f:
    pickle.dump(label_encoders, f)

# %%
with open("xgboost_demand_model.pkl", "wb") as f:
    pickle.dump(best_model, f)
